# %% [markdown]
# ## DQI-I Computation

# %% [markdown]
# Here below we compute the different scores of the DQI-I.

# %% [markdown]
# # Variety
# Variety in serving from each food groups and within each food groups:
#
# - meat/poultry/fish/egg
# - dairy/beans
# - grains
# - fruits
# - vegetables

# %% [markdown]
# To proceed, we need to define the value in grams of a serving to be able to compute it fom our database. Looking at the different literatture and guidelines we define the following:
# - vegetables: 75g
# - fruits: 120g
# - dried fruits: 30g
# - grains, bread: 40g
# - grains rice quinoa etc: 75g
# - tofu: 100g
# - meat: 60g
# - poultry: 80g
# - fish: 100g
# - eggs: 110g
# - beans/pulses: 150g
# - nuts: 30g
# - milk: 200g
# - cream: 25g
# - yogurt: 125g
# - cheese: 30g

# %%
import pandas as pd

# %%
# list of categories
categories = ['vegetable','fruits','dried fruits','grains', 'tofu','meat','poultry','fish','egg','beans', 'pulses','nuts','milk','cream', 'yogurt','cheese'] 
  
# list of servings grams
grams = [75,120,30,75,100,60,80,100,110,150,150,30,200,25,125,30] 
  
#DataFrame servings
servings = pd.DataFrame(list(zip(categories, grams)), 
               columns =['Category', 'Serving_grams']) 
servings
# Out:
#         Category  Serving_grams
# 0      vegetable             75
# 1         fruits            120
# 2   dried fruits             30
# 3         grains             75
# 4           tofu            100
# 5           meat             60
# 6        poultry             80
# 7           fish            100
# 8            egg            110
# 9          beans            150
# 10        pulses            150
# 11          nuts             30
# 12          milk            200
# 13         cream             25
# 14        yogurt            125
# 15        cheese             30

# %% [markdown]
# Getting the list of recipes and ingredients with weights and categories

# %%
List_ingredients_cat_weight = pd.read_csv('Recipes/ExcelFiles_distributions/recipes_ingredients_weights_flattened.csv')

# %% [markdown]
# Attaching Serving size to each row

# %%
List_icwsg = List_ingredients_cat_weight.join(servings.set_index('Category'), on='category')

# %% [markdown]
# Computing the number of servings for each row: in the analysis later on we will use this to sum other the recipes of the day and find how many servings total were consumed during the day.

# %%
tmp = List_icwsg
tmp = tmp.assign(servings = tmp.weight/tmp.Serving_grams)

# %%
tmp
# Out:
#       Unnamed: 0  index  ingr_index  query                       recipe  \
# 0              0      0           0  pasta        Pasta Frittata Recipe
# 1              1      1           1  pasta        Pasta Frittata Recipe
# 2              2      2           2  pasta        Pasta Frittata Recipe
# 3              3      3           3  pasta        Pasta Frittata Recipe
# 4              4      0           0  pasta                 Kimchi Pasta
# ...          ...    ...         ...    ...                          ...
# 3860        3860      7           7   dahl  Broccoli Tarka Dahl recipes
# 3861        3861      8           8   dahl  Broccoli Tarka Dahl recipes
# 3862        3862      9           9   dahl  Broccoli Tarka Dahl recipes
# 3863        3863     10          10   dahl  Broccoli Tarka Dahl recipes
# 3864        3864     11          11   dahl  Broccoli Tarka Dahl recipes
#
#                                          ingredient   weight  \
# 0                             2 cups leftover pasta  210.000
# 1                                     4 eggs beaten  172.000
# 2                              2 tablespoons butter   28.400
# 3     1/2 cup whichever cheese the pasta called for   52.500
# 4                                   2 Tbs olive oil   27.000
# ...                                             ...      ...
# 3860                                 Â¾ tsp tumeric    2.250
# 3861                    Â¼ tsp + 1 tbsp cumin seeds    0.525
# 3862                    Â¼ tsp + 1 tbsp cumin seeds    6.000
# 3863                           2 tbsp vegetable oil   28.000
# 3864          Head of broccoli, broken into florets  608.000
#
#                                             index_match   category  \
# 0            Pasta Frittata Recipe2 cups leftover pasta      other
# 1                    Pasta Frittata Recipe4 eggs beaten        egg
# 2             Pasta Frittata Recipe2 tablespoons butter      other
# 3     Pasta Frittata Recipe1/2 cup whichever cheese ...     cheese
# 4                           Kimchi Pasta2 Tbs olive oil      other
# ...                                                 ...        ...
# 3860          Broccoli Tarka Dahl recipesÂ¾ tsp tumeric      other
# 3861  Broccoli Tarka Dahl recipesÂ¼ tsp + 1 tbsp cum...      other
# 3862  Broccoli Tarka Dahl recipesÂ¼ tsp + 1 tbsp cum...      other
# 3863    Broccoli Tarka Dahl recipes2 tbsp vegetable oil      other
# 3864  Broccoli Tarka Dahl recipesHead of broccoli, b...  vegetable
#
#       Serving_grams  servings
# 0               NaN       NaN
# 1             110.0  1.563636
# 2               NaN       NaN
# 3              30.0  1.750000
# 4               NaN       NaN
# ...             ...       ...
# 3860            NaN       NaN
# 3861            NaN       NaN
# 3862            NaN       NaN
# 3863            NaN       NaN
# 3864           75.0  8.106667
#
# [3865 rows x 11 columns]

# %% [markdown]
# Finally adding the food groups of interest:
# - meat/poultry/fish/egg
# - dairy/beans
# - grains
# - fruits
# - vegetables

# %%
food_groups = ['vegetables','fruits','fruits','grains','dairy_beans','meat_poultry_fish_egg','meat_poultry_fish_egg','meat_poultry_fish_egg','meat_poultry_fish_egg','dairy_beans','dairy_beans','others','dairy_beans','dairy_beans','dairy_beans','dairy_beans','others']

# %%
categories2 = ['vegetable','fruits','dried fruits','grains', 'tofu','meat','poultry','fish','egg','beans', 'pulses','nuts','milk','cream', 'yogurt','cheese','others'] 

index_food_groups = pd.DataFrame(list(zip(categories2, food_groups)), 
               columns =['Category', 'Food_Groups']) 
index_food_groups
# Out:
#         Category            Food_Groups
# 0      vegetable             vegetables
# 1         fruits                 fruits
# 2   dried fruits                 fruits
# 3         grains                 grains
# 4           tofu            dairy_beans
# 5           meat  meat_poultry_fish_egg
# 6        poultry  meat_poultry_fish_egg
# 7           fish  meat_poultry_fish_egg
# 8            egg  meat_poultry_fish_egg
# 9          beans            dairy_beans
# 10        pulses            dairy_beans
# 11          nuts                 others
# 12          milk            dairy_beans
# 13         cream            dairy_beans
# 14        yogurt            dairy_beans
# 15        cheese            dairy_beans
# 16        others                 others

# %%
List_icwsgfg = tmp.join(index_food_groups.set_index('Category'), on='category')

# %%
List_icwsgfg.to_csv('./Recipes/ExcelFiles_distributions/List_ingredients_weights_servings_food_groups.csv')

# %% [markdown]
# # Adequacy
# Compute the % of recommendations from population that is ingested on the following categories:
#
# - Vegetables
# - Fruits
# - Grains
# - Fibres
# - Protein
# - Iron
# - Calcium
# - Vitamin C
# Vegetables,Fruits and Grains will need as for Variety a food group identification mapping. Fibres, Protein, Iron, Calcium and Vitamin C are on the contrary accessible from the result of the API directly from totalNutrients

# %% [markdown]
# We first need to establish the daily recommended values. To do so we first establish a list of references and then will cross-check:
# - UK Source 1: https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/618167/government_dietary_recommendations.pdf
#     In there we get all but the Vegetables, Fruits and Grains recommendations
# - UK Source 2: https://www.nhs.uk/live-well/eat-well/
#     Precise portions of Fruits and Vegetables and also other food groups as well
# - US Source 1:https://health.gov/sites/default/files/2019-09/2015-2020_Dietary_Guidelines.pdf
#     Page 40-45 has cup-equivelent intakes
#     p80 onwards recommendation in cup equivalent based on eenergy intake
# - US Source 2: https://ods.od.nih.gov/HealthInformation/Dietary_Reference_Intakes.aspx#:~:text=Recommended%20Dietary%20Allowance%20(RDA)%3A,assumed%20to%20ensure%20nutritional%20adequacy.
#     not the main categories but the details of the nutirents
# - US Source 3: https://www.choosemyplate.gov/eathealthy
#     Get the main groups in terms of cup equivalents
# - EU Source 1: https://www.efsa.europa.eu/en/interactive-pages/drvs

# %% [markdown]
# Note that we will not differentiate male and female in our experiment as recipes are not distinguishing the serving size for a woman or a man.
# For Fruits and Vegetables, we indicate in ADRthe serving portion and will compute if in total we have 5 fruits and veggies per day or not.

# %%
ADR_list = ['vegetable','fruits','dried fruits','fruit juice','grains','Fiber','Protein','Iron','Calcium','Vitamin C']

# %%
ADR_list_value = [80,80,30,150,200,28,55,8.5,850,90]

# %%
ADR = pd.DataFrame(list(zip(ADR_list, ADR_list_value)), 
               columns =['Category', 'Daily Value(g,g,g,g,g,g,g,mg,mg,mg)'])

# %%
ADR
# Out:
#        Category  Daily Value(g,g,g,g,g,g,g,mg,mg,mg)
# 0     vegetable                                 80.0
# 1        fruits                                 80.0
# 2  dried fruits                                 30.0
# 3   fruit juice                                150.0
# 4        grains                                200.0
# 5         Fiber                                 28.0
# 6       Protein                                 55.0
# 7          Iron                                  8.5
# 8       Calcium                                850.0
# 9     Vitamin C                                 90.0

# %% [markdown]
# First we will pull the Recipes in order for Vegeteblaes, Fruits and Grains info, using the list of ingrdients

# %%
List_ingredients_cat_weight = pd.read_csv('Recipes/ExcelFiles_distributions/recipes_ingredients_weights_flattened.csv')
pivot=List_ingredients_cat_weight.pivot_table('weight', 'recipe', 'category_refined')
pivot = pivot.fillna(0)
Recipes_ADR_vfg = pivot[['dried fruits','fruits','fruit juice','vegetable','grains']]
Recipes_ADR_vfg.insert(0,'recipes',pivot.index)
Recipes_ADR_vfg = Recipes_ADR_vfg.reset_index()

# %%
Recipes_ADR_final.head()
# Out:
#                                                                      recipe  \
# ("Wine & Cheese" Burger,)                            "Wine & Cheese" Burger
# (15 minute lasagne,)                                      15 minute lasagne
# (A Lot Like Lasagna,)                                    A Lot Like Lasagna
# (A.1. Cajun Prime Rib Steak,)                    A.1. Cajun Prime Rib Steak
# (Almond & honey dairy-free ice cream,)  Almond & honey dairy-free ice cream
#
#                                         vegetable  fruits  dried fruits  \
# ("Wine & Cheese" Burger,)                2.083738     0.0           0.0
# (15 minute lasagne,)                     1.000000     0.0           0.0
# (A Lot Like Lasagna,)                    4.393750     0.0           0.0
# (A.1. Cajun Prime Rib Steak,)            0.000000     0.0           0.0
# (Almond & honey dairy-free ice cream,)   0.000000     0.0           0.0
#
#                                         fruit juice  grains     Fiber  \
# ("Wine & Cheese" Burger,)                       0.0     0.0  0.442198
# (15 minute lasagne,)                            0.0     0.0  0.117143
# (A Lot Like Lasagna,)                           0.0     0.0  0.572788
# (A.1. Cajun Prime Rib Steak,)                   0.0     0.0  0.072786
# (Almond & honey dairy-free ice cream,)          0.0     0.0  0.111065
#
#                                          Protein      Iron   Calcium  \
# ("Wine & Cheese" Burger,)               3.219314  2.660328  1.257170
# (15 minute lasagne,)                    3.617779  2.158030  2.137353
# (A Lot Like Lasagna,)                   2.551142  1.556346  2.682747
# (A.1. Cajun Prime Rib Steak,)           1.516799  1.323404  0.144220
# (Almond & honey dairy-free ice cream,)  0.670726  0.304581  2.579958
#
#                                         Vitamin C
# ("Wine & Cheese" Burger,)                0.399568
# (15 minute lasagne,)                     0.194667
# (A Lot Like Lasagna,)                    2.478973
# (A.1. Cajun Prime Rib Steak,)            0.076504
# (Almond & honey dairy-free ice cream,)   0.032444

# %% [markdown]
# Then we will do the other nutrients part using the list of recipes and nutrients

# %%
List_recipes_nutrients = pd.read_csv('Recipes/ExcelFiles_distributions/recipe_nutrients.csv')
Recipes_ADR_fpicvc = List_recipes_nutrients[['recipe','Protein','Fiber','Iron','Calcium','Vitamin C']]

# %% [markdown]
# Combining all in one

# %%
Recipes_ADR = Recipes_ADR_vfg.join(Recipes_ADR_fpicvc.set_index('recipe'), on='recipes')
Recipes_ADR_tmp= Recipes_ADR [['vegetable','fruits','dried fruits', 'fruit juice', 'grains', 'Fiber', 'Protein', 'Iron', 'Calcium', 'Vitamin C']]
Recipes_ADR_tmp.index = Recipes_ADR[['recipe']]      #getting rid of the two recipes columns ot be able to do divisions
ADRT = ADR[['Daily Value(g,g,g,g,g,g,g,mg,mg,mg)']].T    #trasnposing ADR, keeping only the vlues and putting names in columns names
ADRT.columns = ADR_list
tmp = Recipes_ADR_tmp.div(ADRT.iloc[0], axis = 'columns')
Recipes_ADR.index = Recipes_ADR[['recipe']]
tmp.insert(0,'recipe',Recipes_ADR[['recipe']])
tmp.reset_index()
Recipes_ADR_final=tmp.fillna(0)
Recipes_ADR_final['TotalFruits']= Recipes_ADR_final['dried fruits'] + Recipes_ADR_final['fruits'] + Recipes_ADR_final['fruit juice']
Recipes_ADR_final
# Out:
#                                                                                          recipe  \
# ("Wine & Cheese" Burger,)                                                "Wine & Cheese" Burger
# (15 minute lasagne,)                                                          15 minute lasagne
# (A Lot Like Lasagna,)                                                        A Lot Like Lasagna
# (A.1. Cajun Prime Rib Steak,)                                        A.1. Cajun Prime Rib Steak
# (Almond & honey dairy-free ice cream,)                      Almond & honey dairy-free ice cream
# ...                                                                                         ...
# (Yellow Rice,)                                                                      Yellow Rice
# (Yummy Slice-And-Bake Cookies,)                                    Yummy Slice-And-Bake Cookies
# (Zucchini With Thyme,)                                                      Zucchini With Thyme
# (Zucchini-Tofu Croquettes,)                                            Zucchini-Tofu Croquettes
# ({Vegan} Peanut Butter & Honey Muffins recipes,)  {Vegan} Peanut Butter & Honey Muffins recipes
#
#                                                   vegetable  fruits  \
# ("Wine & Cheese" Burger,)                          2.083738     0.0
# (15 minute lasagne,)                               1.000000     0.0
# (A Lot Like Lasagna,)                              4.393750     0.0
# (A.1. Cajun Prime Rib Steak,)                      0.000000     0.0
# (Almond & honey dairy-free ice cream,)             0.000000     0.0
# ...                                                     ...     ...
# (Yellow Rice,)                                     0.143750     0.0
# (Yummy Slice-And-Bake Cookies,)                    0.000000     0.0
# (Zucchini With Thyme,)                             3.084952     0.0
# (Zucchini-Tofu Croquettes,)                        4.037500     0.0
# ({Vegan} Peanut Butter & Honey Muffins recipes,)   0.000000     0.0
#
#                                                   dried fruits  fruit juice  \
# ("Wine & Cheese" Burger,)                                  0.0          0.0
# (15 minute lasagne,)                                       0.0          0.0
# (A Lot Like Lasagna,)                                      0.0          0.0
# (A.1. Cajun Prime Rib Steak,)                              0.0          0.0
# (Almond & honey dairy-free ice cream,)                     0.0          0.0
# ...                                                        ...          ...
# (Yellow Rice,)                                             0.0          0.0
# (Yummy Slice-And-Bake Cookies,)                            0.0          0.0
# (Zucchini With Thyme,)                                     0.0          0.0
# (Zucchini-Tofu Croquettes,)                                0.0          0.0
# ({Vegan} Peanut Butter & Honey Muffins recipes,)           0.0          0.0
#
#                                                   grains     Fiber   Protein  \
# ("Wine & Cheese" Burger,)                            0.0  0.442198  3.219314
# (15 minute lasagne,)                                 0.0  0.117143  3.617779
# (A Lot Like Lasagna,)                                0.0  0.572788  2.551142
# (A.1. Cajun Prime Rib Steak,)                        0.0  0.072786  1.516799
# (Almond & honey dairy-free ice cream,)               0.0  0.111065  0.670726
# ...                                                  ...       ...       ...
# (Yellow Rice,)                                       0.0  0.166107  0.571305
# (Yummy Slice-And-Bake Cookies,)                      0.0  0.772696  1.206064
# (Zucchini With Thyme,)                               0.0  0.232396  0.135344
# (Zucchini-Tofu Croquettes,)                          0.0  0.296806  0.627196
# ({Vegan} Peanut Butter & Honey Muffins recipes,)     0.0  0.211243  0.536976
#
#                                                       Iron   Calcium  \
# ("Wine & Cheese" Burger,)                         2.660328  1.257170
# (15 minute lasagne,)                              2.158030  2.137353
# (A Lot Like Lasagna,)                             1.556346  2.682747
# (A.1. Cajun Prime Rib Steak,)                     1.323404  0.144220
# (Almond & honey dairy-free ice cream,)            0.304581  2.579958
# ...                                                    ...       ...
# (Yellow Rice,)                                    1.673598  0.136194
# (Yummy Slice-And-Bake Cookies,)                   2.750053  0.751406
# (Zucchini With Thyme,)                            0.509525  0.160734
# (Zucchini-Tofu Croquettes,)                       0.910404  1.122820
# ({Vegan} Peanut Butter & Honey Muffins recipes,)  0.399539  0.895350
#
#                                                   Vitamin C  TotalFruits
# ("Wine & Cheese" Burger,)                          0.399568          0.0
# (15 minute lasagne,)                               0.194667          0.0
# (A Lot Like Lasagna,)                              2.478973          0.0
# (A.1. Cajun Prime Rib Steak,)                      0.076504          0.0
# (Almond & honey dairy-free ice cream,)             0.032444          0.0
# ...                                                     ...          ...
# (Yellow Rice,)                                     0.028294          0.0
# (Yummy Slice-And-Bake Cookies,)                    0.015328          0.0
# (Zucchini With Thyme,)                             1.162256          0.0
# (Zucchini-Tofu Croquettes,)                        0.650231          0.0
# ({Vegan} Peanut Butter & Honey Muffins recipes,)   0.003500          0.0
#
# [461 rows x 12 columns]

# %%
Recipes_ADR_final.to_csv('Recipes/ExcelFiles_distributions/recipes_ADR_final.csv')

# %% [markdown]
# # Moderation

# %% [markdown]
# Moderation uses simple derivation from nutrients but 2 elements need to be converted from g to KCal as thy are expressed in % of Energy. To do so we use : http://www.fao.org/3/y5022e/y5022e04.htm:
#  - Fat: 37 kJ/g or 9 kcal/g
#  - Saturated Fat: 37 kJ/g or 9 kcal/g

# %%
List_nutrients = pd.read_csv('Recipes/ExcelFiles_distributions/recipe_nutrients.csv')

# %%
List_Moderation = List_nutrients[['recipe','Energy','Cholesterol','Sodium','Fat','Saturated']]

# %%
List_Moderation['Fat kJ'] = List_Moderation['Fat']*9
List_Moderation['Saturates kJ'] = List_Moderation['Saturated']*9
# Out:
# <ipython-input-30-981525a13f9c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_Moderation['Fat kJ'] = List_Moderation['Fat']*9
# <ipython-input-30-981525a13f9c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_Moderation['Saturates kJ'] = List_Moderation['Saturated']*9

# %%
List_Moderation
List_Moderation.to_csv('../Python/Recipes/ExcelFiles_distributions/recipes_moderation_fat_cholesterol_sodium.csv')

# %%
List_Moderation.head()
# Out:
#                    recipe       Energy  Cholesterol       Sodium         Fat  \
# 0       15 minute lasagne  2481.454188   798.477594  2244.947250  151.956789
# 1  BLT Pasta Salad Recipe  1472.476789   234.361586  3590.334442  115.312226
# 2               Bean Soup   686.432949    70.635733  5734.439462   34.131767
# 3            Best Lasagne  5113.542644   801.321835  6752.616944  268.516570
# 4   Buffalo Chicken Salad  3260.402000   937.975000  2549.376000  244.269840
#
#     Saturated
# 0   90.130535
# 1   52.092601
# 2    5.453360
# 3  111.761098
# 4   61.992339

# %% [markdown]
# ### Empty Calorie food

# %% [markdown]
# Nutrient density is the ratio of nutrients to energy in a certain amount of food consumed compared with the recommended levels.
# *Example:*
#  Vitamin C nutrient density of 100 g of apple consumed by a 20-y-old woman is 2.83
#  - Vitamin C (100g apple) = 5.7 mg
#  - Energy (100g apple) = 247 kJ
#  - Recommended Vitamin C intake = 75 mg
#  - Recommended Energy intake = 9211 kJ
#  - Nutrient Ratio = (5.7 mg/75 mg)/(247 kJ/9211 kJ)
#
# In DQI-I, if the sum of nutrient densities across nutrients examined in a food is < 1 then the food is considered to be an empty calorie food.
# Then, if the energy supplied by empty calorie food is > 10% of total energy intake per day, owest score is assigned.

# %% [markdown]
# Since we do not have access to the components per ingredients but only at receipe level, we will compute a nutrient density score at recipe level using the following nutrients, leveraging insights from https://academic.oup.com/jn/article/139/8/1549/4670510:
#  - Protein
#  - Fiber
#  - Vitamin A,C,E

# %%
List_Empty_food = List_nutrients[['recipe','Energy','Protein','Fiber','Vitamin A','Vitamin C','Vitamin E']]

# %%
ADR_list_mod = ['Energy','Protein','Fiber','Vitamin A','Vitamin C','Vitamin E']
ADR_value_mod = [2000,55,28,750,90,13]
ADR_Mod = pd.DataFrame(list(zip(ADR_list_mod, ADR_value_mod)), 
               columns =['Category', 'Daily Value(kcal,g,g,mug,mg,mg)'])

# %%
List_Empty_food[['Nutrient Density']] = List_Empty_food[[]]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-54e9c470fb20> in <module>
# ----> 1 List_Empty_food[['Nutrient Density']] = List_Empty_food[[]]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2933             self._setitem_frame(key, value)
#    2934         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 2935             self._setitem_array(key, value)
#    2936         else:
#    2937             # set column
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    2959             if isinstance(value, DataFrame):
#    2960                 if len(value.columns) != len(key):
# -> 2961                     raise ValueError("Columns must be same length as key")
#    2962                 for k1, k2 in zip(key, value.columns):
#    2963                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
List_Empty_food
# Out:
#                            recipe       Energy     Protein      Fiber  \
# 0               15 minute lasagne  2481.454188  198.977857   3.280000
# 1          BLT Pasta Salad Recipe  1472.476789   89.590416   4.501000
# 2                       Bean Soup   686.432949   19.843082   9.640625
# 3                    Best Lasagne  5113.542644  259.404899  36.788043
# 4           Buffalo Chicken Salad  3260.402000  232.370070   7.974600
# ..                            ...          ...         ...        ...
# 456  Sweet Vegan Chickpea CrÃªpes  1527.577200   34.743570  11.623500
# 457     Tofu & spinach cannelloni  2074.305625   92.678517  32.550333
# 458            Tofu Banana Mousse   397.178663   19.993442   8.338420
# 459          Tofu With Crab Sauce   437.318348   60.736829   3.675790
# 460      Zucchini-Tofu Croquettes   614.076734   34.495794   8.310556
#
#        Vitamin A   Vitamin C  Vitamin E
# 0    1187.870227   17.520000   6.330443
# 1     891.137769   27.026000   2.294087
# 2    1056.947750   33.237000   5.307455
# 3    1553.964780  175.021789  14.169776
# 4    2444.206000   90.231100  10.128840
# ..           ...         ...        ...
# 456   114.080000    0.000000  12.331138
# 457  2078.507292  226.360375  21.468200
# 458     7.022000   20.632693   0.307245
# 459     3.747476    5.687958   2.860320
# 460   108.096000   58.520796   2.840750
#
# [461 rows x 7 columns]

# %%
Recipes_ADR_mod_tmp = List_Empty_food.drop(columns=['recipe'])
Recipes_ADR_mod_tmp.index = List_Empty_food[['recipe']]      #getting rid of the two recipes columns ot be able to do divisions
ADR_Mod_T = ADR_Mod[['Daily Value(kcal,g,g,mug,mg,mg)']].T    #trasnposing ADR, keeping only the vlues and putting names in columns names
ADR_Mod_T.columns = ADR_list_mod
tmp = Recipes_ADR_mod_tmp.div(ADR_Mod_T.iloc[0], axis = 'columns')
List_Empty_food.index = List_Empty_food[['recipe']]
tmp.insert(0,'recipe',List_Empty_food[['recipe']])
tmp.reset_index()
Recipes_ADR_Mod_final=tmp.fillna(0)
Recipes_ADR_Mod_final
# Out:
#                                                        recipe    Energy  \
# (15 minute lasagne,)                        15 minute lasagne  1.240727
# (BLT Pasta Salad Recipe,)              BLT Pasta Salad Recipe  0.736238
# (Bean Soup,)                                        Bean Soup  0.343216
# (Best Lasagne,)                                  Best Lasagne  2.556771
# (Buffalo Chicken Salad,)                Buffalo Chicken Salad  1.630201
# ...                                                       ...       ...
# (Sweet Vegan Chickpea CrÃªpes,)  Sweet Vegan Chickpea CrÃªpes  0.763789
# (Tofu & spinach cannelloni,)        Tofu & spinach cannelloni  1.037153
# (Tofu Banana Mousse,)                      Tofu Banana Mousse  0.198589
# (Tofu With Crab Sauce,)                  Tofu With Crab Sauce  0.218659
# (Zucchini-Tofu Croquettes,)          Zucchini-Tofu Croquettes  0.307038
#
#                                   Protein     Fiber  Vitamin A  Vitamin C  \
# (15 minute lasagne,)             3.617779  0.117143   1.583827   0.194667
# (BLT Pasta Salad Recipe,)        1.628917  0.160750   1.188184   0.300289
# (Bean Soup,)                     0.360783  0.344308   1.409264   0.369300
# (Best Lasagne,)                  4.716453  1.313859   2.071953   1.944687
# (Buffalo Chicken Salad,)         4.224910  0.284807   3.258941   1.002568
# ...                                   ...       ...        ...        ...
# (Sweet Vegan Chickpea CrÃªpes,)  0.631701  0.415125   0.152107   0.000000
# (Tofu & spinach cannelloni,)     1.685064  1.162512   2.771343   2.515115
# (Tofu Banana Mousse,)            0.363517  0.297801   0.009363   0.229252
# (Tofu With Crab Sauce,)          1.104306  0.131278   0.004997   0.063200
# (Zucchini-Tofu Croquettes,)      0.627196  0.296806   0.144128   0.650231
#
#                                  Vitamin E
# (15 minute lasagne,)              0.486957
# (BLT Pasta Salad Recipe,)         0.176468
# (Bean Soup,)                      0.408266
# (Best Lasagne,)                   1.089983
# (Buffalo Chicken Salad,)          0.779142
# ...                                    ...
# (Sweet Vegan Chickpea CrÃªpes,)   0.948549
# (Tofu & spinach cannelloni,)      1.651400
# (Tofu Banana Mousse,)             0.023634
# (Tofu With Crab Sauce,)           0.220025
# (Zucchini-Tofu Croquettes,)       0.218519
#
# [461 rows x 7 columns]

# %% [markdown]
# Unfortunately we cannot compute it ==> WE DROP IT

# %% [markdown]
# # Overall Balance

# %% [markdown]
# Overall Balance is computing Macronutrient ratio (carbohydrate, protein, fat) and Fatty Acid Ratio.

# %% [markdown]
# Macronutrient Ratio will ne computed once recipes have been selected. For test with only 1 recipes, we will emasure departure from mean ie only on one recipe level.
# - 55-65/10-15/15-25 --> 6
# - 52-68/9-16/13-27 --> 4
# - 50-70/8-17/12-30 --> 2
# - Others --> 0
# To compute this ratio of energy, we need to use conversion tables from http://www.fao.org/3/y5022e/y5022e04.htm:
#  - Carbohydrates: 17 kcal/g
#  - Protein:4 kcal/g
#  - Fat: 9 kcal/g

# %% [markdown]
# Fatty Acid Ratio will be computed from the follwing rule:
# - P/S = 1-1.5 / M/S = 1-1.5 -->4
# - P/S = 0-8-1.7 / M/S = 0.8-1.7 -->2
# - Others --> 0

# %%
List_nutrients = pd.read_csv('Recipes/ExcelFiles_distributions/recipe_nutrients.csv')

# %%
List_nutrients.columns
# Out:
# Index(['recipe', 'Calcium', 'Carbs', 'Cholesterol', 'Energy', 'Fat', 'Fiber',
#        'Folate (food)', 'Folate equivalent (total)', 'Folic acid', 'Iron',
#        'Magnesium', 'Monounsaturated', 'Niacin (B3)', 'Phosphorus',
#        'Polyunsaturated', 'Potassium', 'Protein', 'Riboflavin (B2)',
#        'Saturated', 'Sodium', 'Sugars', 'Sugars, added', 'Thiamin (B1)',
#        'Trans', 'Vitamin A', 'Vitamin B12', 'Vitamin B6', 'Vitamin C',
#        'Vitamin D', 'Vitamin E', 'Vitamin K', 'Water', 'Zinc'],
#       dtype='object')

# %%
List_balance = List_nutrients[['recipe','Energy','Carbs','Protein', 'Fat', 'Monounsaturated','Polyunsaturated','Saturated']]

# %%
List_balance['Carbs kJ'] = List_balance['Carbs']*17
List_balance['Protein kJ'] = List_balance['Protein']*4
List_balance['Fat kJ'] = List_balance['Fat']*9
List_balance['Monounaturated kJ'] = List_balance['Monounsaturated']*9
List_balance['Polyunsaturated kJ'] = List_balance['Polyunsaturated']*9
List_balance['Saturated kJ'] = List_balance['Saturated']*9
# Out:
# <ipython-input-8-df78bd2a3054>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_balance['Carbs kJ'] = List_balance['Carbs']*17
# <ipython-input-8-df78bd2a3054>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_balance['Protein kJ'] = List_balance['Protein']*4
# <ipython-input-8-df78bd2a3054>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_balance['Fat kJ'] = List_balance['Fat']*9
# <ipython-input-8-df78bd2a3054>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_balance['Monounaturated kJ'] = List_balance['Monounsaturated']*9
# <ipython-input-8-df78bd2a3054>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_balance['Polyunsaturated kJ'] = List_balance['Polyunsaturated']*9
# <ipython-input-8-df78bd2a3054>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   List_balance['Saturated kJ'] = List_balance['Saturated']*9

# %%
List_balance.to_csv('../Python/Recipes/ExcelFiles_distributions/recipes_balance.csv')
